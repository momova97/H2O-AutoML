# %%
# !pip install h2o

# %%
import h2o
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321..... not found.
# Attempting to start a local H2O server...
#   Java Version: openjdk version "21.0.2" 2024-01-16 LTS; OpenJDK Runtime Environment Microsoft-8905927 (build 21.0.2+13-LTS); OpenJDK 64-Bit Server VM Microsoft-8905927 (build 21.0.2+13-LTS, mixed mode, sharing)
#   Starting server from /usr/local/python/3.10.13/lib/python3.10/site-packages/h2o/backend/bin/h2o.jar
#   Ice root: /tmp/tmp6ym2ehwv
#   JVM stdout: /tmp/tmp6ym2ehwv/h2o_codespace_started_from_python.out
#   JVM stderr: /tmp/tmp6ym2ehwv/h2o_codespace_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  --------------------------------
# H2O_cluster_uptime:         02 secs
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.46.0.1
# H2O_cluster_version_age:    3 days
# ...
